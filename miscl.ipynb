# %% [markdown]
# <a href="https://colab.research.google.com/github/niran-j2005/jr/blob/main/miscl.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# this file contains examples of break,continue and matrix handling

# %%
#break statement
for i in range(6):
  if i==4:
    break
  print(i)
# Out:
# 0
# 1
# 2
# 3

# %%
 #continue statement
 for i in range(6):
  if i==4:
    continue
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 5

# %% [markdown]
# lists of list

# %%
#to handle the marks of 4 subjects of three students
marks_students=[
    [50,30,60,45],
    [80,40,55,47],
    [55,45,65,75]
]
print(marks_students[0])
print(marks_students[2][2])
# Out:
# [50, 30, 60, 45]
# 65

# %%
marks_stud=[
    [50,30,60,45],
    [80,40,55,47],
    [55,45,65,75]
]
print(marks_stud)
for  i in range (3):
  #print(marks_stud[i])
  print(f"marks of students {i+1}")
  for j in range(4):
    print(marks_stud[i][j])
# Out:
# [[50, 30, 60, 45], [80, 40, 55, 47], [55, 45, 65, 75]]
# marks of students 1
# 50
# 30
# 60
# 45
# marks of students 2
# 80
# 40
# 55
# 47
# marks of students 3
# 55
# 45
# 65
# 75

# %%
#identity operator
marks_students1=[23,45,67]
marks_students2=[23,45,67]
x=marks_students2
print(marks_students1==marks_students2)
print(marks_students1 is marks_students2)
print(x==marks_students2)
print(x is marks_students1)
# Out:
# True
# False
# True
# False

# %%
students=[
    "name":
]
